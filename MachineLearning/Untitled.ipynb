# %%
# link: https://www.academia.edu/41417553/S%C3%A1ch_Deep_Learning_c%C6%A1_b%E1%BA%A3n

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
np.random.seed(0)
X = np.random.rand(100, 1) * 10  # 100 điểm dữ liệu ngẫu nhiên
y = 2.5 * X + np.random.randn(100, 1) * 2  # Hồi quy tuyến tính với nhiễu

# Tạo DataFrame và lưu vào CSV
data = pd.DataFrame({'X': X.flatten(), 'y': y.flatten()})
data.to_csv('data_linear.csv', index=False)

# %%
data = pd.read_csv('data_linear.csv').values

# %%
print(data)
# Out:
# [[ 5.48813504 11.39003792]
#  [ 7.15189366 19.68138713]
#  [ 6.02763376 16.00040928]
#  [ 5.44883183 10.5495922 ]
#  [ 4.23654799 13.56787437]
#  [ 6.45894113 19.93913118]
#  [ 4.37587211 13.29723942]
#  [ 8.91773001 21.93447535]
#  [ 9.63662761 21.95006377]
#  [ 3.83441519 11.69494142]
#  [ 7.91725038 18.98677206]
#  [ 5.2889492  15.66726313]
#  [ 5.68044561 14.61766398]
#  [ 9.25596638 25.09319403]
#  [ 0.71036058  2.48863425]
#  [ 0.871293    3.59137883]
#  [ 0.20218397  0.52645998]
#  [ 8.32619846 24.38723713]
#  [ 7.78156751 19.70774296]
#  [ 8.70012148 22.55428243]
#  [ 9.78618342 28.23175995]
#  [ 7.99158564 17.28344598]
#  [ 4.61479362  8.99601406]
#  [ 7.80529176 21.45202282]
#  [ 1.18274426  0.61061384]
#  [ 6.39921021 19.8852679 ]
#  [ 1.43353287  2.75659422]
#  [ 9.44668917 22.1218133 ]
#  [ 5.21848322 16.8920921 ]
#  [ 4.1466194  13.32757808]
#  [ 2.64555612 10.34900822]
#  [ 7.74233689 21.16793155]
#  [ 4.56150332  9.68130694]
#  [ 5.68433949 18.03097863]
#  [ 0.187898   -0.06626173]
#  [ 6.17635497 17.04580022]
#  [ 6.12095723 17.196897  ]
#  [ 6.16933997 15.11332974]
#  [ 9.43748079 24.8218607 ]
#  [ 6.81820299 18.88992082]
#  [ 3.59507901  9.74054858]
#  [ 4.37031954  8.72699726]
#  [ 6.97631196 18.03725625]
#  [ 0.60225472  4.15840858]
#  [ 6.66766715 15.28003217]
#  [ 6.7063787  16.46667766]
#  [ 2.10382561  4.38925692]
#  [ 1.28926298  6.9216849 ]
#  [ 3.15428351  9.23029829]
#  [ 3.63710771  9.90769295]
#  [ 5.7019677  12.71508711]
#  [ 4.38601513 12.04353622]
#  [ 9.88373838 23.36068063]
#  [ 1.02044811  2.61478139]
#  [ 2.08876756  3.95022675]
#  [ 1.61309518  5.38560454]
#  [ 6.53108325 17.48088977]
#  [ 2.53291603  5.91569255]
#  [ 4.66310773 12.44978275]
#  [ 2.44425592  3.92451678]
#  [ 1.58969584  0.99172441]
#  [ 1.10375141  3.63816193]
#  [ 6.56329589 16.74158673]
#  [ 1.38182951  4.72463666]
#  [ 1.96582362  9.68084859]
#  [ 3.68725171 11.10708824]
#  [ 8.2099323  18.6991863 ]
#  [ 0.97101276  4.66156447]
#  [ 8.37944907 18.31680787]
#  [ 0.96098408  1.47929099]
#  [ 9.76459465 24.27500341]
#  [ 4.68651202 15.14296548]
#  [ 9.76761088 22.92951756]
#  [ 6.0484552  13.46826092]
#  [ 7.39263579 18.28468444]
#  [ 0.39187792 -0.34726177]
#  [ 2.82806963  9.32344591]
#  [ 1.20196561  0.84505101]
#  [ 2.96140198  5.10856763]
#  [ 1.18727719  2.09255288]
#  [ 3.17983179  6.95351458]
#  [ 4.14262995 14.21563897]
#  [ 0.64147496  3.50252902]
#  [ 6.92472119 17.48690547]
#  [ 5.66601454 11.71416532]
#  [ 2.65389491  8.32346323]
#  [ 5.23248053 11.08077064]
#  [ 0.93940511 -0.74102942]
#  [ 5.75946496 16.77472197]
#  [ 9.29296198 23.86629016]
#  [ 3.18568952  9.80594146]
#  [ 6.6741038  17.3227148 ]
#  [ 1.31797862  5.00860778]
#  [ 7.16327204 16.60612892]
#  [ 2.89406093  5.16666664]
#  [ 1.83191362  5.94297309]
#  [ 5.86512935 13.05600404]
#  [ 0.20107546 -0.8764109 ]
#  [ 8.28940029 19.81243572]
#  [ 0.04695476  0.15234522]]

# %%
N = data.shape[0]
x = data[:, 0].reshape(-1, 1)
y = data[:, 1].reshape(-1, 1)
plt.scatter(x, y)
plt.xlabel('mét vuông')
plt.ylabel('giá')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

N = data.shape[0]
x = data[:, 0].reshape(-1, 1)
y = data[:, 1].reshape(-1, 1)

x = np.hstack((np.ones((N, 1)), x))  # Thêm cột bias để x có kích thước (N, 2)
w = np.array([0.0, 1.0]).reshape(-1, 1)  # Đảm bảo w có kiểu float

numOfIteration = 100
cost = np.zeros((numOfIteration, 1))
learning_rate = 0.000001

for i in range(1, numOfIteration):
    r = np.dot(x, w) - y
    cost[i] = 0.5 * np.sum(r * r)
    w[0] -= learning_rate * np.sum(r)
    w[1] -= learning_rate * np.sum(np.multiply(r, x[:, 1].reshape(-1, 1)))
    print(cost[i])

predict = np.dot(x, w)
plt.plot((x[0][1], x[N-1][1]), (predict[0], predict[N-1]), 'r')
plt.show()
# Out:
# [3912.86344311]
# [3889.57707439]
# [3866.43671652]
# [3843.44145397]
# [3820.59037695]
# [3797.88258139]
# [3775.31716888]
# [3752.89324664]
# [3730.6099275]
# [3708.46632984]
# [3686.46157758]
# [3664.59480012]
# [3642.86513232]
# [3621.27171449]
# [3599.81369229]
# [3578.49021676]
# [3557.30044428]
# [3536.24353648]
# [3515.31866027]
# [3494.52498779]
# [3473.86169635]
# [3453.32796844]
# [3432.92299166]
# [3412.64595871]
# [3392.49606735]
# [3372.47252039]
# [3352.57452559]
# [3332.80129574]
# [3313.15204851]
# [3293.62600651]
# [3274.22239722]
# [3254.94045295]
# [3235.77941083]
# [3216.73851278]
# [3197.81700546]
# [3179.01414027]
# [3160.3291733]
# [3141.76136529]
# [3123.30998163]
# [3104.97429231]
# [3086.7535719]
# [3068.64709952]
# [3050.65415881]
# [3032.7740379]
# [3015.00602937]
# [2997.34943026]
# [2979.80354201]
# [2962.36767043]
# [2945.04112568]
# [2927.82322228]
# [2910.71327901]
# [2893.71061892]
# [2876.81456935]
# [2860.0244618]
# [2843.339632]
# [2826.75941983]
# [2810.28316931]
# [2793.91022859]
# [2777.63994988]
# [2761.47168947]
# [2745.40480768]
# [2729.43866884]
# [2713.57264127]
# [2697.80609725]
# [2682.13841299]
# [2666.56896862]
# [2651.09714815]
# [2635.72233946]
# [2620.44393426]
# [2605.26132808]
# [2590.17392023]
# [2575.1811138]
# [2560.28231562]
# [2545.47693623]
# [2530.76438987]
# [2516.14409447]
# [2501.61547157]
# [2487.17794638]
# [2472.8309477]
# [2458.57390789]
# [2444.40626289]
# [2430.32745219]
# [2416.33691876]
# [2402.43410909]
# [2388.61847313]
# [2374.88946428]
# [2361.24653936]
# [2347.68915862]
# [2334.21678566]
# [2320.82888747]
# [2307.52493437]
# [2294.30440001]
# [2281.16676134]
# [2268.11149856]
# [2255.13809518]
# [2242.24603791]
# [2229.43481669]
# [2216.70392466]
# [2204.05285814]
